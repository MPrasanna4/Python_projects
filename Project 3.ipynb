# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("sentimentdataset.csv")# importing the excel filesin csv
data
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
data.shape
# Out:
# (732, 15)

# %%
data.isnull()
# Out:
#      Unnamed: 0.1  Unnamed: 0   Text  Sentiment  Timestamp   User  Platform  \
# 0           False       False  False      False      False  False     False
# 1           False       False  False      False      False  False     False
# 2           False       False  False      False      False  False     False
# 3           False       False  False      False      False  False     False
# 4           False       False  False      False      False  False     False
# ..            ...         ...    ...        ...        ...    ...       ...
# 727         False       False  False      False      False  False     False
# 728         False       False  False      False      False  False     False
# 729         False       False  False      False      False  False     False
# 730         False       False  False      False      False  False     False
# 731         False       False  False      False      False  False     False
#
# ...

# %%
data.isnull().any()
# Out:
# Unnamed: 0.1    False
# Unnamed: 0      False
# Text            False
# Sentiment       False
# Timestamp       False
# User            False
# Platform        False
# Hashtags        False
# Retweets        False
# Likes           False
# Country         False
# Year            False
# Month           False
# Day             False
# Hour            False
# dtype: bool

# %%
data.isna().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
# What is the overall distribution of sentiments (positive, negative, neutral) across the posts?
# !pip install textblob

# %%
data.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
from textblob import TextBlob

# Example list of posts (replace with your own posts)
posts = pd.read_csv("sentimentdataset.csv")
# Function to classify sentiment
def classify_sentiment(posts):
    # Create a TextBlob object
    blob = TextBlob(post)
    # Get the polarity score (ranges from -1 to 1)
    polarity = blob.sentiment.polarity
    
    # Classify sentiment based on polarity
    if polarity > 0:
        return 'positive'
    elif polarity < 0:
        return 'negative'
    else:
        return 'neutral'

# Initialize counters for sentiments
sentiment_counts = {'positive': 0, 'negative': 0, 'neutral': 0}

# Analyze sentiment for each post
for post in posts:
    sentiment = classify_sentiment(post)
    sentiment_counts[sentiment] += 1

# Print the distribution of sentiments
print("Sentiment Distribution:")
print(f"Positive: {sentiment_counts['positive']}")
print(f"Negative: {sentiment_counts['negative']}")
print(f"Neutral: {sentiment_counts['neutral']}")

classify_sentiment(post)
# Out:
# Sentiment Distribution:
# Positive: 0
# Negative: 0
# Neutral: 15
# 'neutral'

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#Which platform generates the most engagement in terms of likes and retweets?
import pandas as pd
import matplotlib.pyplot as plt

data['total_engagement'] = data['Likes'] + data['Retweets']

# Identify the platform with the maximum engagement
max_engagement_platform = data.loc[data['total_engagement'].idxmax()]

# Display results
print("Engagement Data:")

print(f"\nPlatform with highest engagement: {max_engagement_platform['Platform']}")
print(f"Total Engagement: {max_engagement_platform['total_engagement']}")

# Visualize the engagement data
plt.figure(figsize=(10, 6))
plt.bar(data['Platform'], data['total_engagement'], color='skyblue')
plt.title('Total Engagement by Platform')
plt.xlabel('Social Media Platform')
plt.ylabel('Total Engagement (Likes + Retweets)')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Engagement Data:
#
# Platform with highest engagement:  Instagram
# Total Engagement: 120.0

# %%
data.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
#
#              Timestamp            User    Platform  \
# 0  2023-01-15 12:30:00   User123         Twitter
# 1  2023-01-15 08:45:00   CommuterX       Twitter
#
#                                      Hashtags  Retweets  Likes     Country  \
# 0   #Nature #Park                                  15.0   30.0   USA
# 1   #Traffic #Morning                               5.0   10.0   Canada
#
#    Year  Month  Day  Hour  total_engagement
# 0  2023      1   15    12              45.0
# 1  2023      1   15     8              15.0

# %%
import tweepy
import pandas as pd

# Set up your Twitter API credentials
API_KEY = 'your_api_key'
API_SECRET = 'your_api_secret'
ACCESS_TOKEN = 'your_access_token'
ACCESS_TOKEN_SECRET = 'your_access_token_secret'

# Authenticate to Twitter
auth = tweepy.OAuth1UserHandler(API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

def get_user_engagement(screen_name):
    # Fetch the last 30 tweets from the user
    my_tweets = api.user_timeline(screen_name=screen_name, count=30, include_rts=True, tweet_mode='extended')
    
    total_likes = 0
    total_retweets = 0
    
    for tweet in my_tweets:
        total_likes += tweet.favorite_count
        total_retweets += tweet.retweet_count
        
    # Calculate average engagement per tweet
    average_engagement = (total_likes + total_retweets) / len(my_tweets) if my_tweets else 0
    return average_engagement

# List of users to analyze
usernames = data['User'].tolist() # Replace with actual usernames

# Create a DataFrame to store results
engagement_data = pd.DataFrame(columns=['User', 'Average Engagement'])

# Calculate engagement for each user
for username in usernames:
    avg_engagement = get_user_engagement(usernames)
    engagement_data = engagement_data.append({'User': username, 'Average Engagement': avg_engagement}, ignore_index=True)

# Sort by average engagement in descending order
engagement_data.sort_values(by='Average Engagement', ascending=False, inplace=True)

# Display the results
print(engagement_data)
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# Cell In[47], line 37
#      35 # Calculate engagement for each user
#      36 for username in usernames:
# ---> 37     avg_engagement = get_user_engagement(usernames)
#      38     engagement_data = engagement_data.append({'User': username, 'Average Engagement': avg_engagement}, ignore_index=True)
#      40 # Sort by average engagement in descending order
#
# Cell In[47], line 16, in get_user_engagement(screen_name)
#      14 def get_user_engagement(screen_name):
#      15     # Fetch the last 30 tweets from the user
# ---> 16     my_tweets = api.user_timeline(screen_name=screen_name, count=30, include_rts=True, tweet_mode='extended')
#      18     total_likes = 0
#      19     total_retweets = 0
#
# File ~\anaconda3\Lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
# ...
