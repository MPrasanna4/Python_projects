# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("training_data_week_1.csv")# importing the excel filesin csv
data
# Out:
#           Id Province/State Country/Region      Lat     Long       Date  \
# 0          1            NaN    Afghanistan  33.0000  65.0000  1/22/2020
# 1          2            NaN    Afghanistan  33.0000  65.0000  1/23/2020
# 2          3            NaN    Afghanistan  33.0000  65.0000  1/24/2020
# 3          4            NaN    Afghanistan  33.0000  65.0000  1/25/2020
# 4          5            NaN    Afghanistan  33.0000  65.0000  1/26/2020
# ...      ...            ...            ...      ...      ...        ...
# 17887  26378            NaN         Zambia -15.4167  28.2833  3/20/2020
# 17888  26379            NaN         Zambia -15.4167  28.2833  3/21/2020
# 17889  26380            NaN         Zambia -15.4167  28.2833  3/22/2020
# 17890  26381            NaN         Zambia -15.4167  28.2833  3/23/2020
# 17891  26382            NaN         Zambia -15.4167  28.2833  3/24/2020
#
#        ConfirmedCases  Fatalities  day_from_jan_first  temp   min   max  \
# ...

# %%
data.tail(5)
# Out:
#           Id Province/State Country/Region      Lat     Long       Date  \
# 17887  26378            NaN         Zambia -15.4167  28.2833  3/20/2020
# 17888  26379            NaN         Zambia -15.4167  28.2833  3/21/2020
# 17889  26380            NaN         Zambia -15.4167  28.2833  3/22/2020
# 17890  26381            NaN         Zambia -15.4167  28.2833  3/23/2020
# 17891  26382            NaN         Zambia -15.4167  28.2833  3/24/2020
#
#        ConfirmedCases  Fatalities  day_from_jan_first  temp   min   max  \
# 17887               2           0                  80  70.6  62.6  81.9
# 17888               2           0                  81  71.3  66.2  81.5
# 17889               3           0                  82  72.1  67.1  80.4
# 17890               3           0                  83  71.7  66.2  80.6
# 17891               3           0                  84  72.6  60.3  84.2
#
#          stp  slp  dewp        rh        ah  wdsp   prcp  fog
# ...

# %%
data.head(5)
# Out:
#    Id Province/State Country/Region   Lat  Long       Date  ConfirmedCases  \
# 0   1            NaN    Afghanistan  33.0  65.0  1/22/2020               0
# 1   2            NaN    Afghanistan  33.0  65.0  1/23/2020               0
# 2   3            NaN    Afghanistan  33.0  65.0  1/24/2020               0
# 3   4            NaN    Afghanistan  33.0  65.0  1/25/2020               0
# 4   5            NaN    Afghanistan  33.0  65.0  1/26/2020               0
#
#    Fatalities  day_from_jan_first  temp   min   max    stp     slp  dewp  \
# 0           0                  22  42.6  33.6  54.9  999.9  1024.3  27.4
# 1           0                  23  42.0  32.7  55.9  999.9  1020.8  22.8
# 2           0                  24  40.1  36.9  43.2  999.9  1018.6  34.5
# 3           0                  25  46.0  37.9  56.3  999.9  1018.0  37.8
# 4           0                  26  42.8  36.1  53.1  999.9  1014.8  33.2
#
#          rh        ah  wdsp   prcp  fog
# ...

# %%
data.isna().sum()
# Out:
# Id                       0
# Province/State        9702
# Country/Region           0
# Lat                      0
# Long                     0
# Date                     0
# ConfirmedCases           0
# Fatalities               0
# day_from_jan_first       0
# temp                     0
# min                    137
# max                     16
# stp                      0
# slp                   6947
# dewp                   618
# rh                     618
# ah                     618
# wdsp                     0
# prcp                     0
# fog                      0
# dtype: int64

# %%
data.isnull()
# Out:
#           Id  Province/State  Country/Region    Lat   Long   Date  \
# 0      False            True           False  False  False  False
# 1      False            True           False  False  False  False
# 2      False            True           False  False  False  False
# 3      False            True           False  False  False  False
# 4      False            True           False  False  False  False
# ...      ...             ...             ...    ...    ...    ...
# 17887  False            True           False  False  False  False
# 17888  False            True           False  False  False  False
# 17889  False            True           False  False  False  False
# 17890  False            True           False  False  False  False
# 17891  False            True           False  False  False  False
#
#        ConfirmedCases  Fatalities  day_from_jan_first   temp    min    max  \
# 0               False       False               False  False  False  False
# ...

# %%
data.dropna()
# Out:
#           Id                Province/State  Country/Region      Lat      Long  \
# 504      745  Australian Capital Territory       Australia -35.4735  149.0124
# 505      746  Australian Capital Territory       Australia -35.4735  149.0124
# 506      747  Australian Capital Territory       Australia -35.4735  149.0124
# 507      748  Australian Capital Territory       Australia -35.4735  149.0124
# 508      749  Australian Capital Territory       Australia -35.4735  149.0124
# ...      ...                           ...             ...      ...       ...
# 17572  25913                United Kingdom  United Kingdom  55.3781   -3.4360
# 17573  25914                United Kingdom  United Kingdom  55.3781   -3.4360
# 17574  25915                United Kingdom  United Kingdom  55.3781   -3.4360
# 17575  25916                United Kingdom  United Kingdom  55.3781   -3.4360
# 17576  25917                United Kingdom  United Kingdom  55.3781   -3.4360
#
# ...

# %%
data.isna().sum()
# Out:
# Id                       0
# Province/State        9702
# Country/Region           0
# Lat                      0
# Long                     0
# Date                     0
# ConfirmedCases           0
# Fatalities               0
# day_from_jan_first       0
# temp                     0
# min                    137
# max                     16
# stp                      0
# slp                   6947
# dewp                   618
# rh                     618
# ah                     618
# wdsp                     0
# prcp                     0
# fog                      0
# dtype: int64

# %%
df=data.dropna()
print(df)
# Out:
#           Id                Province/State  Country/Region      Lat      Long  \
# 504      745  Australian Capital Territory       Australia -35.4735  149.0124
# 505      746  Australian Capital Territory       Australia -35.4735  149.0124
# 506      747  Australian Capital Territory       Australia -35.4735  149.0124
# 507      748  Australian Capital Territory       Australia -35.4735  149.0124
# 508      749  Australian Capital Territory       Australia -35.4735  149.0124
# ...      ...                           ...             ...      ...       ...
# 17572  25913                United Kingdom  United Kingdom  55.3781   -3.4360
# 17573  25914                United Kingdom  United Kingdom  55.3781   -3.4360
# 17574  25915                United Kingdom  United Kingdom  55.3781   -3.4360
# 17575  25916                United Kingdom  United Kingdom  55.3781   -3.4360
# 17576  25917                United Kingdom  United Kingdom  55.3781   -3.4360
#
# ...

# %%
df
# Out:
#           Id                Province/State  Country/Region      Lat      Long  \
# 504      745  Australian Capital Territory       Australia -35.4735  149.0124
# 505      746  Australian Capital Territory       Australia -35.4735  149.0124
# 506      747  Australian Capital Territory       Australia -35.4735  149.0124
# 507      748  Australian Capital Territory       Australia -35.4735  149.0124
# 508      749  Australian Capital Territory       Australia -35.4735  149.0124
# ...      ...                           ...             ...      ...       ...
# 17572  25913                United Kingdom  United Kingdom  55.3781   -3.4360
# 17573  25914                United Kingdom  United Kingdom  55.3781   -3.4360
# 17574  25915                United Kingdom  United Kingdom  55.3781   -3.4360
# 17575  25916                United Kingdom  United Kingdom  55.3781   -3.4360
# 17576  25917                United Kingdom  United Kingdom  55.3781   -3.4360
#
# ...

# %%
df.isna()
# Out:
#           Id  Province/State  Country/Region    Lat   Long   Date  \
# 504    False           False           False  False  False  False
# 505    False           False           False  False  False  False
# 506    False           False           False  False  False  False
# 507    False           False           False  False  False  False
# 508    False           False           False  False  False  False
# ...      ...             ...             ...    ...    ...    ...
# 17572  False           False           False  False  False  False
# 17573  False           False           False  False  False  False
# 17574  False           False           False  False  False  False
# 17575  False           False           False  False  False  False
# 17576  False           False           False  False  False  False
#
#        ConfirmedCases  Fatalities  day_from_jan_first   temp    min    max  \
# 504             False       False               False  False  False  False
# ...

# %%
# !pip install pandas matplotlib seaborn

# %%
#How do confirmed cases and fatalities vary over time for different regions?
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Filter the dataset for specific regions:(e.g., countries)
regions = data['Country/Region'].tolist()  # Add more regions as needed
filtered_data = data[data['Province/State'].isin(regions)]

# Convert date column to datetime format
filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])

# Set up the plot
plt.figure(figsize=(14, 7))

# Plot confirmed cases and fatalities over time for each region
for region in regions:
    region_data = filtered_data[filtered_data['Province/State'] == region]
    plt.plot(region_data['Date'], region_data['total_cases'], label=f'{region} - Confirmed Cases')
    plt.plot(region_data['Date'], region_data['total_deaths'], label=f'{region} - Fatalities', linestyle='--')

# Customize the plot
plt.title('COVID-19 Confirmed Cases and Fatalities Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14812\3960131586.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
#Which countries or regions have the highest and lowest total confirmed cases and fatalities?
aggregated_data = df.groupby('Country/Region')[['ConfirmedCases', 'Fatalities']].sum()

# Sorting the regions based on confirmed cases and fatalities
highest_confirmed = aggregated_data['ConfirmedCases'].idxmax()
lowest_confirmed = aggregated_data['ConfirmedCases'].idxmin()

highest_fatalities = aggregated_data['Fatalities'].idxmax()
lowest_fatalities = aggregated_data['Fatalities'].idxmin()

# Output the results
print(f"Country/Region with the highest confirmed cases: {highest_confirmed}")
print(f"Country/Region with the lowest confirmed cases: {lowest_confirmed}")
print(f"Country/Region with the highest fatalities: {highest_fatalities}")
print(f"Country/Region with the lowest fatalities: {lowest_fatalities}")
# Out:
# Country/Region with the highest confirmed cases: China
# Country/Region with the lowest confirmed cases: Cruise Ship
# Country/Region with the highest fatalities: China
# Country/Region with the lowest fatalities: Cruise Ship

# %%
# Is there a correlation between temperature (temp) and the number of confirmed cases or fatalities?
# !pip install pandas matplotlib scipy

# %%
temperature_data = pd.read_csv('training_data_week_4.csv')
temperature_data
# Out:
#           Id Country/Region\n       Date  ConfirmedCases  Fatalities  \
# 0          1      Afghanistan  1/22/2020               0           0
# 1          2      Afghanistan  1/23/2020               0           0
# 2          3      Afghanistan  1/24/2020               0           0
# 3          4      Afghanistan  1/25/2020               0           0
# 4          5      Afghanistan  1/26/2020               0           0
# ...      ...              ...        ...             ...         ...
# 24409  35642         Zimbabwe   4/4/2020               9           1
# 24410  35643         Zimbabwe   4/5/2020               9           1
# 24411  35644         Zimbabwe   4/6/2020              10           1
# 24412  35645         Zimbabwe   4/7/2020              11           2
# 24413  35646         Zimbabwe   4/8/2020              11           3
#
#       country+province        Lat       Long  day_from_jan_first  temp   min  \
# ...

# %%
temperature_data.isnull()
# Out:
#           Id  Country/Region\n   Date  ConfirmedCases  Fatalities  \
# 0      False             False  False           False       False
# 1      False             False  False           False       False
# 2      False             False  False           False       False
# 3      False             False  False           False       False
# 4      False             False  False           False       False
# ...      ...               ...    ...             ...         ...
# 24409  False             False  False           False       False
# 24410  False             False  False           False       False
# 24411  False             False  False           False       False
# 24412  False             False  False           False       False
# 24413  False             False  False           False       False
#
#        country+province    Lat   Long  day_from_jan_first   temp    min  \
# 0                 False  False  False               False  False  False
# ...

# %%
temperature_data.dropna()
# Out:
#           Id Country/Region\n       Date  ConfirmedCases  Fatalities  \
# 0          1      Afghanistan  1/22/2020               0           0
# 1          2      Afghanistan  1/23/2020               0           0
# 2          3      Afghanistan  1/24/2020               0           0
# 3          4      Afghanistan  1/25/2020               0           0
# 4          5      Afghanistan  1/26/2020               0           0
# ...      ...              ...        ...             ...         ...
# 24019  35072        Venezuela   4/4/2020             155           7
# 24020  35073        Venezuela   4/5/2020             159           7
# 24021  35074        Venezuela   4/6/2020             165           7
# 24022  35075        Venezuela   4/7/2020             165           7
# 24023  35076        Venezuela   4/8/2020             167           9
#
#       country+province      Lat     Long  day_from_jan_first  temp   min  \
# ...

# %%
# Is there a correlation between temperature (temp) and the number of confirmed cases or fatalities?
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load COVID-19 and temperature data
# Replace with your actual dataset paths or URLs
#covid_data_url = 'https://example.com/covid_data.csv'  # CSV with 'date', 'confirmed_cases', 'deaths', 'temperature'
covid_data = pd.read_csv('training_data_week_4.csv')

covid_data.dropna()

# Preview the dataset
print(covid_data.head())

# Convert date column to datetime format
covid_data['Date'] = pd.to_datetime(covid_data['Date'])

# Group by date to get daily totals (if necessary)
daily_data = covid_data.groupby('Date').agg({
    'ConfirmedCases': 'sum',
    'slp': 'sum',
    'temp': 'mean'  # Assuming temperature is recorded daily
}).reset_index()

# Calculate correlation coefficients
correlation_cases_temp = daily_data['ConfirmedCases'].corr(daily_data['temp'])
correlation_deaths_temp = daily_data['slp'].corr(daily_data['temp'])

print(f'Correlation between confirmed cases and temperature: {correlation_cases_temp}')
print(f'Correlation between deaths and temperature: {correlation_deaths_temp}')

# Visualization
plt.figure(figsize=(14, 6))

# Plot confirmed cases vs temperature
plt.subplot(1, 2, 1)
sns.scatterplot(data=daily_data, x='temp', y='ConfirmedCases')
plt.title('Confirmed Cases vs Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Confirmed Cases')

# Plot deaths vs temperature
plt.subplot(1, 2, 2)
sns.scatterplot(data=daily_data, x='temp', y='slp')
plt.title('Deaths vs Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Deaths')

plt.tight_layout()
plt.show()
# Out:
#    Id Country/Region\n       Date  ConfirmedCases  Fatalities  \
# 0   1      Afghanistan  1/22/2020               0           0
# 1   2      Afghanistan  1/23/2020               0           0
# 2   3      Afghanistan  1/24/2020               0           0
# 3   4      Afghanistan  1/25/2020               0           0
# 4   5      Afghanistan  1/26/2020               0           0
#
#   country+province   Lat  Long  day_from_jan_first  temp   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  42.6  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  42.0  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  40.1  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  46.0  37.9  56.3  999.9
# 4     Afghanistan-  33.0  65.0                  26  42.8  36.1  53.1  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# 0  1024.3  27.4  0.545709  0.186448   9.4   0.00    0
# ...
