# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("StudentPerformanceFactors.csv")# importing the excel filesin csv
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
null_counts = data.isnull().sum()
print(null_counts)
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
data.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
# 7             25          78                  Low                High
# 8             17          94               Medium                High
# 9             23          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# ...

# %%
data.tail(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
correlation = data["Hours_Studied"].corr(data["Exam_Score"])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.44545495407528213

# %%
low = data[data['Motivation_Level'] < low]
print(low)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 low = data[data['Motivation_Level'] < low]
#       2 print(low)
#
# NameError: name 'low' is not defined

# %%
# How does the number of hours studied per week correlate with the final exam score?
plt.scatter(data["Hours_Studied"], data["Exam_Score"])
plt.xlabel("Hours Studied per Week")
plt.ylabel("Final Exam Score")
plt.title("Correlation between Study Hours and Exam Score")
plt.show()

# %%
df = pd.DataFrame(data)

average_sleep = df['Sleep_Hours'].mean()
print(average_sleep)
# Out:
# 7.029060087785682

# %%
correlation = df['Sleep_Hours'].corr(df['Exam_Score'])
print(correlation)
# Out:
# -0.017021628571502547

# %%
plt.scatter(df['Sleep_Hours'], df['Exam_Score'])
plt.title('Sleep_Hours vs. Exam_Score')
plt.xlabel('Sleep Hours')
plt.ylabel('Exam Score')
plt.show()

# %%
# Do private school students perform better in exams than public school students?
def analyze_exam_performance(data): # By using function
    private_avg = data[data['School_Type'] == 'Private']['Exam_Score'].mean()
    public_avg = data[data['School_Type'] == 'Public']['Exam_Score'].mean()
    
    if private_avg > public_avg:
        print("Based on the data, private school students tend to perform better on exams.")
    elif public_avg > private_avg:
        print("Based on the data, public school students tend to perform better on exams.") 
    else: 
        print("No significant difference observed between private and public school students.")
    print(f"Average exam score for private school students: {private_avg}")
    print(f"Average exam score for public school students: {public_avg}")
df = pd.DataFrame(data)

analyze_exam_performance(df)
# Out:
# Based on the data, private school students tend to perform better on exams.
# Average exam score for private school students: 67.28770532603285
# Average exam score for public school students: 67.21291866028709
