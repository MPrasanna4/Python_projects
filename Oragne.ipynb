# %%
import pandas as pd
import numpy as np
import seaborn as snp
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Orange Quality Data.csv")
data
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
data.isna().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
data.dropna()
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
data.isna().any()
# Out:
# Size (cm)             False
# Weight (g)            False
# Brix (Sweetness)      False
# pH (Acidity)          False
# Softness (1-5)        False
# HarvestTime (days)    False
# Ripeness (1-5)        False
# Color                 False
# Variety               False
# Blemishes (Y/N)       False
# Quality (1-5)         False
# dtype: bool

# %%
# Is there a correlation between the size (Size (cm)) and the weight (Weight (g)) of the fruit?
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

correlation = data['Size (cm)'].corr(data['Weight (g)'])
print(f'Correlation between Size and Weight: {correlation}')

# Visualization
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Size (cm)', y='Weight (g)', hue='Variety', s=100)
plt.title('Correlation between Size and Weight of Fruit')
plt.xlabel('Size (cm)')
plt.ylabel('Weight (g)')
plt.grid()
plt.show()
# Out:
# Correlation between Size and Weight: 0.30534816456201685

# %%
print(data.columns)
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
#How does the sweetness (Brix) of the fruit correlate with its acidity (pH)? Do sweeter fruits have lower acidity?
correlation = data['Brix (Sweetness)'].corr(data['pH (Acidity)'])
print(f'Correlation between Sweetness and Acidity: {correlation}')

# Visualization
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Brix (Sweetness)', y='pH (Acidity)', hue='Variety', s=100)
plt.title('Correlation between Sweetness and Acidity of Fruit')
plt.xlabel('Sweetness (Brix)')
plt.ylabel('Acidity (pH)')
plt.grid()
plt.axhline(y=4.0, color='r', linestyle='--', label='Neutral pH')
plt.legend()
plt.show()
# Out:
# Correlation between Sweetness and Acidity: -0.30007995138340415

# %%
# How does the softness (Softness (1-5)) of the fruit relate to its ripeness (Ripeness (1-5))?
correlation = data['Softness (1-5)'].corr(data['Ripeness (1-5)'])
print(f'Correlation between Softness and Ripeness: {correlation}')

# Visualization
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Softness (1-5)', y='Ripeness (1-5)', hue='Variety', s=100)
plt.title('Correlation between Softness and Ripeness of Fruit')
plt.xlabel('Softness (1-5)')
plt.ylabel('Ripeness (1-5)')
plt.xticks(range(1, 6))  # Set x-ticks for clarity
plt.yticks(range(1, 6))  # Set y-ticks for clarity
plt.grid()
plt.show()
# Out:
# Correlation between Softness and Ripeness: -0.20240387765979326

# %%
print(data.columns)
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
#Do fruits with blemishes (Blemishes (Y/N)) tend to have lower ripeness or softness levels?
data['Blemishes (Y/N)'] = data['Blemishes (Y/N)'].astype('category')

# Calculate average ripeness and softness by blemish status
average_scores = data.groupby('Blemishes (Y/N)').agg(
    Average_Softness=('Softness (1-5)', 'mean'),
    Average_Ripeness=('Ripeness (1-5)', 'mean')
).reset_index()

# Display results
print("Average Softness and Ripeness by Blemish Status:")
print(average_scores)

# Visualization
plt.figure(figsize=(12, 6))

# Bar plot for Average Softness by Blemish Status
plt.subplot(1, 2, 1)
sns.barplot(data=average_scores, x='Blemishes (Y/N)', y='Average_Softness', palette='viridis', legend='False')
plt.title('Average Softness by Blemish Status')
plt.xlabel('Blemishes (Y/N)')
plt.ylabel('Average Softness (1-5)')
plt.xticks(rotation=45)

# Bar plot for Average Ripeness by Blemish Status
plt.subplot(1, 2, 2)
sns.barplot(data=average_scores, x='Blemishes (Y/N)', y='Average_Ripeness', palette='magma')
plt.title('Average Ripeness by Blemish Status')
plt.xlabel('Blemishes (Y/N)')
plt.ylabel('Average Ripeness (1-5)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12708\2291946745.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_scores = data.groupby('Blemishes (Y/N)').agg(
# C:\Users\admin\AppData\Local\Temp\ipykernel_12708\2291946745.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=average_scores, x='Blemishes (Y/N)', y='Average_Softness', palette='viridis', legend='False')
# Average Softness and Ripeness by Blemish Status:
#             Blemishes (Y/N)  Average_Softness  Average_Ripeness
# 0                         N          2.986577          3.906040
# 1                 N (Minor)          4.000000          4.000000
# ...

# %%
print(data.columns)
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
# How do different fruit varieties (Variety) differ in terms of size, weight, sweetness, acidity, and ripeness?
average_values = data.groupby('Variety').mean().reset_index()

# Display results
print("Average Size, Weight, Sweetness, Acidity and Ripeness by Variety:")
print(average_values)

# Visualization
plt.figure(figsize=(14, 10))

# Bar plots for each attribute
attributes = ['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)', 'Ripeness (1-5)']
for i in range(len(attributes)):
    plt.subplot(3, 2, i + 1)
    sns.barplot(data=average_values.sort_values(by=attributes[i]), x='Variety', y=attributes[i], palette='viridis')
    plt.title(f'Average {attributes[i]} by Variety')
    plt.xlabel('Fruit Variety')
    plt.ylabel(attributes[i])
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...
